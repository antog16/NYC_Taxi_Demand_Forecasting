# %%
import pandas as pd
import numpy as np
import xgboost as xgb
from sklearn.model_selection import train_test_split, KFold, cross_val_score
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import r2_score, root_mean_squared_error
import optuna
import seaborn as sns
import matplotlib.pyplot as plt
from Funciones import feature_engineering_shuffle

# %%
df = pd.read_parquet("data/train_data/trips_weather_merged.parquet") #Load train dataset

# %%
df = feature_engineering_shuffle(df) #Apply feature engineering function

# %%
df = pd.get_dummies(df,columns=["weekday","is_weekend", "rush_hour","is_holiday","LocationID"],drop_first=True,dtype=float)

# %%
df_cluster_0 = df[df["cluster"]==0]
y = df_cluster_0["Total_Trips"]
X = df_cluster_0.drop(columns=["Total_Trips","tpep_pickup_hour", "Location*Hour","cluster"])

X_train, X_test, y_train, y_test = train_test_split(X,y,random_state=42, shuffle=True, test_size=0.2, stratify=df_cluster_0["Location*Hour"])

# %%
def objective(trial):
    # Define hyperparameter search space
    params = {
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.2, log=True),
        'n_estimators': trial.suggest_int('n_estimators', 300, 400),
        'max_depth': trial.suggest_int('max_depth', 3, 5),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 5),
        'gamma': trial.suggest_float('gamma', 0, 0.3),
        'subsample': trial.suggest_float('subsample', 0.6, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.6, 1.0),
        'reg_alpha': trial.suggest_float('reg_alpha', 0, 10),
        'reg_lambda': trial.suggest_float('reg_lambda', 0, 10),
        'objective': 'reg:squarederror'
    }

    # Define cross-validation strategy
    cv = KFold(n_splits=4, shuffle=True, random_state=42)

    model = xgb.XGBRegressor(**params, random_state=42)

# Perform cross-validation manually to inverse transform predictions
    scores = []
    for train_index, val_index in cv.split(X_train, y_train): # Use the log-transformed target
        X_train_fold, X_val_fold = X_train.iloc[train_index], X_train.iloc[val_index]
        y_train_fold, y_val_fold = y_train.iloc[train_index], y_train.iloc[val_index]

        model.fit(X_train_fold, y_train_fold, verbose=0)
        predictions = model.predict(X_val_fold)

        score = r2_score(y_val_fold, predictions) # Inverse transform true values too for evaluation
        scores.append(score)

    # Return the mean accuracy across all folds
    return np.mean(scores)

study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=30)

# Best hyperparameters
print("Best hyperparameters:", study.best_params)

best_params = study.best_params

model = xgb.XGBRegressor(**best_params, random_seed=42)

model.fit(X_train, y_train, verbose=False)
# Out:
# [I 2025-04-21 21:16:55,403] A new study created in memory with name: no-name-9a8b0a9b-71aa-481f-af4a-17d04d0ffe16
# [I 2025-04-21 21:18:07,063] Trial 0 finished with value: 0.9395004865884085 and parameters: {'learning_rate': 0.03001439243346843, 'n_estimators': 386, 'max_depth': 3, 'min_child_weight': 4, 'gamma': 0.15330921243655396, 'subsample': 0.973384796110239, 'colsample_bytree': 0.6583917397876912, 'reg_alpha': 7.137414299973055, 'reg_lambda': 1.2589475091397928}. Best is trial 0 with value: 0.9395004865884085.
# [I 2025-04-21 21:20:02,818] Trial 1 finished with value: 0.9402608764054909 and parameters: {'learning_rate': 0.014068571171210034, 'n_estimators': 383, 'max_depth': 4, 'min_child_weight': 1, 'gamma': 0.010281686788825883, 'subsample': 0.9062985510419754, 'colsample_bytree': 0.8698892961752074, 'reg_alpha': 9.274567941989812, 'reg_lambda': 7.296366977962286}. Best is trial 1 with value: 0.9402608764054909.
# [I 2025-04-21 21:22:06,622] Trial 2 finished with value: 0.9548900788656027 and parameters: {'learning_rate': 0.07019135513352767, 'n_estimators': 384, 'max_depth': 5, 'min_child_weight': 5, 'gamma': 0.03698967412578504, 'subsample': 0.7188765913134141, 'colsample_bytree': 0.8576778193989614, 'reg_alpha': 9.632136947981412, 'reg_lambda': 3.284442141190662}. Best is trial 2 with value: 0.9548900788656027.
# [I 2025-04-21 21:23:18,802] Trial 3 finished with value: 0.9547595541381371 and parameters: {'learning_rate': 0.17746237617131902, 'n_estimators': 313, 'max_depth': 4, 'min_child_weight': 5, 'gamma': 0.21805193933590467, 'subsample': 0.8150998865340378, 'colsample_bytree': 0.6161845081811922, 'reg_alpha': 4.824870975044091, 'reg_lambda': 5.227216031335024}. Best is trial 2 with value: 0.9548900788656027.
# [I 2025-04-21 21:24:33,813] Trial 4 finished with value: 0.9389898256210412 and parameters: {'learning_rate': 0.03226177276799903, 'n_estimators': 326, 'max_depth': 3, 'min_child_weight': 1, 'gamma': 0.07937276765548061, 'subsample': 0.7968262164095383, 'colsample_bytree': 0.7281855682606051, 'reg_alpha': 4.261032195343274, 'reg_lambda': 6.013568625820631}. Best is trial 2 with value: 0.9548900788656027.
# [I 2025-04-21 21:26:03,265] Trial 5 finished with value: 0.9405002623720784 and parameters: {'learning_rate': 0.037247319281531716, 'n_estimators': 348, 'max_depth': 3, 'min_child_weight': 2, 'gamma': 0.10142862222927664, 'subsample': 0.7478767611986669, 'colsample_bytree': 0.9970784465927485, 'reg_alpha': 6.857753125008415, 'reg_lambda': 5.505454860055181}. Best is trial 2 with value: 0.9548900788656027.
# [I 2025-04-21 21:27:29,835] Trial 6 finished with value: 0.9552097716339674 and parameters: {'learning_rate': 0.08938500281023777, 'n_estimators': 367, 'max_depth': 5, 'min_child_weight': 4, 'gamma': 0.23301675636663988, 'subsample': 0.987248509483801, 'colsample_bytree': 0.6111346705701198, 'reg_alpha': 6.4986891651070025, 'reg_lambda': 4.333318637393938}. Best is trial 6 with value: 0.9552097716339674.
# [I 2025-04-21 21:29:11,903] Trial 7 finished with value: 0.9509955693720707 and parameters: {'learning_rate': 0.06097736265989273, 'n_estimators': 386, 'max_depth': 4, 'min_child_weight': 5, 'gamma': 0.0026915010071658307, 'subsample': 0.9981216390175262, 'colsample_bytree': 0.9225465355370155, 'reg_alpha': 3.2520909694069946, 'reg_lambda': 3.778340309867676}. Best is trial 6 with value: 0.9552097716339674.
# [I 2025-04-21 21:30:39,748] Trial 8 finished with value: 0.9441344749434359 and parameters: {'learning_rate': 0.058406597926113614, 'n_estimators': 343, 'max_depth': 3, 'min_child_weight': 4, 'gamma': 0.2484476247957097, 'subsample': 0.8411941780493641, 'colsample_bytree': 0.8831890667629483, 'reg_alpha': 4.867726245968993, 'reg_lambda': 8.996452305747852}. Best is trial 6 with value: 0.9552097716339674.
# [I 2025-04-21 21:32:15,015] Trial 9 finished with value: 0.9483340977048871 and parameters: {'learning_rate': 0.04204914045599736, 'n_estimators': 383, 'max_depth': 4, 'min_child_weight': 4, 'gamma': 0.1280235165290378, 'subsample': 0.6727314181689062, 'colsample_bytree': 0.8351511890979765, 'reg_alpha': 9.732521295966164, 'reg_lambda': 1.895736499602858}. Best is trial 6 with value: 0.9552097716339674.
# [I 2025-04-21 21:33:46,145] Trial 10 finished with value: 0.9567107255710734 and parameters: {'learning_rate': 0.13520675347515096, 'n_estimators': 365, 'max_depth': 5, 'min_child_weight': 3, 'gamma': 0.29902355585182805, 'subsample': 0.6019136737764593, 'colsample_bytree': 0.7458492676813171, 'reg_alpha': 0.957302203481305, 'reg_lambda': 9.875194596246997}. Best is trial 10 with value: 0.9567107255710734.
# [I 2025-04-21 21:35:28,493] Trial 11 finished with value: 0.9569961289911318 and parameters: {'learning_rate': 0.14893421014201996, 'n_estimators': 366, 'max_depth': 5, 'min_child_weight': 3, 'gamma': 0.2953722121605498, 'subsample': 0.6043170750013949, 'colsample_bytree': 0.7491206921601118, 'reg_alpha': 1.4991141234253726, 'reg_lambda': 9.740898798005343}. Best is trial 11 with value: 0.9569961289911318.
# [I 2025-04-21 21:36:43,943] Trial 12 finished with value: 0.9569795984136077 and parameters: {'learning_rate': 0.1761003394343806, 'n_estimators': 358, 'max_depth': 5, 'min_child_weight': 3, 'gamma': 0.2992026924306113, 'subsample': 0.6054421398791175, 'colsample_bytree': 0.7492332207919085, 'reg_alpha': 1.0809508490665376, 'reg_lambda': 9.783160175703534}. Best is trial 11 with value: 0.9569961289911318.
# [I 2025-04-21 21:38:08,533] Trial 13 finished with value: 0.9572108644274611 and parameters: {'learning_rate': 0.19283316859037697, 'n_estimators': 365, 'max_depth': 5, 'min_child_weight': 3, 'gamma': 0.2981926937850828, 'subsample': 0.6014926762493229, 'colsample_bytree': 0.7506793378590275, 'reg_alpha': 0.3709684614889286, 'reg_lambda': 8.076609578310912}. Best is trial 13 with value: 0.9572108644274611.
# [I 2025-04-21 21:39:30,370] Trial 14 finished with value: 0.9564164575013484 and parameters: {'learning_rate': 0.11125515239499008, 'n_estimators': 337, 'max_depth': 5, 'min_child_weight': 2, 'gamma': 0.18984223365127917, 'subsample': 0.6624860272035077, 'colsample_bytree': 0.7974225601034034, 'reg_alpha': 0.1140751325666276, 'reg_lambda': 7.793810352192187}. Best is trial 13 with value: 0.9572108644274611.
# [I 2025-04-21 21:41:34,637] Trial 15 finished with value: 0.9567634465305581 and parameters: {'learning_rate': 0.12461281067973473, 'n_estimators': 370, 'max_depth': 5, 'min_child_weight': 2, 'gamma': 0.25542637860563644, 'subsample': 0.6562353231943329, 'colsample_bytree': 0.6903721878709492, 'reg_alpha': 2.640272956647446, 'reg_lambda': 8.008386681379704}. Best is trial 13 with value: 0.9572108644274611.
# [I 2025-04-21 21:44:26,294] Trial 16 finished with value: 0.9461398113683763 and parameters: {'learning_rate': 0.015255690695318708, 'n_estimators': 356, 'max_depth': 5, 'min_child_weight': 3, 'gamma': 0.2664253212707411, 'subsample': 0.7171111672825481, 'colsample_bytree': 0.7952826629251465, 'reg_alpha': 2.2274385306573063, 'reg_lambda': 6.762016513894847}. Best is trial 13 with value: 0.9572108644274611.
# [I 2025-04-21 21:46:16,005] Trial 17 finished with value: 0.9560226855899573 and parameters: {'learning_rate': 0.19887039009221993, 'n_estimators': 398, 'max_depth': 4, 'min_child_weight': 2, 'gamma': 0.18256353288328173, 'subsample': 0.6186436674180079, 'colsample_bytree': 0.6848579890098548, 'reg_alpha': 1.614547446342557, 'reg_lambda': 8.574228380521776}. Best is trial 13 with value: 0.9572108644274611.
# [I 2025-04-21 21:48:07,109] Trial 18 finished with value: 0.9477234608289339 and parameters: {'learning_rate': 0.021110268175887615, 'n_estimators': 334, 'max_depth': 5, 'min_child_weight': 3, 'gamma': 0.19654265490732753, 'subsample': 0.6955140072986326, 'colsample_bytree': 0.7609452991724852, 'reg_alpha': 3.5299253891826146, 'reg_lambda': 6.651630853555037}. Best is trial 13 with value: 0.9572108644274611.
# [I 2025-04-21 21:50:10,744] Trial 19 finished with value: 0.9562163799464511 and parameters: {'learning_rate': 0.08745677090993545, 'n_estimators': 400, 'max_depth': 5, 'min_child_weight': 2, 'gamma': 0.26714100205134483, 'subsample': 0.7529726586319931, 'colsample_bytree': 0.7086444250914725, 'reg_alpha': 0.2911985754174422, 'reg_lambda': 8.938313065838758}. Best is trial 13 with value: 0.9572108644274611.
# [I 2025-04-21 21:51:55,398] Trial 20 finished with value: 0.9547255665990841 and parameters: {'learning_rate': 0.14802011831487336, 'n_estimators': 373, 'max_depth': 4, 'min_child_weight': 4, 'gamma': 0.28739633858202757, 'subsample': 0.6379538688563143, 'colsample_bytree': 0.6525194309612005, 'reg_alpha': 1.9023836708088797, 'reg_lambda': 9.58955992697927}. Best is trial 13 with value: 0.9572108644274611.
# [I 2025-04-21 21:53:39,526] Trial 21 finished with value: 0.9569773889832717 and parameters: {'learning_rate': 0.19336258136698503, 'n_estimators': 356, 'max_depth': 5, 'min_child_weight': 3, 'gamma': 0.29643782920141826, 'subsample': 0.6027324654901179, 'colsample_bytree': 0.7579858426875336, 'reg_alpha': 1.188717725280515, 'reg_lambda': 9.929896626101165}. Best is trial 13 with value: 0.9572108644274611.
# [I 2025-04-21 21:55:22,854] Trial 22 finished with value: 0.9562629454010848 and parameters: {'learning_rate': 0.10258207012965002, 'n_estimators': 357, 'max_depth': 5, 'min_child_weight': 3, 'gamma': 0.27600988294605505, 'subsample': 0.6318588228802817, 'colsample_bytree': 0.7765831355641569, 'reg_alpha': 0.7955672890673154, 'reg_lambda': 8.334004085591811}. Best is trial 13 with value: 0.9572108644274611.
# [I 2025-04-21 21:56:42,304] Trial 23 finished with value: 0.9575655020584227 and parameters: {'learning_rate': 0.16147509326207363, 'n_estimators': 360, 'max_depth': 5, 'min_child_weight': 3, 'gamma': 0.23255551949345582, 'subsample': 0.6919010893031594, 'colsample_bytree': 0.828723545372629, 'reg_alpha': 0.0353238029105275, 'reg_lambda': 9.005881861726515}. Best is trial 23 with value: 0.9575655020584227.
# [I 2025-04-21 21:57:54,912] Trial 24 finished with value: 0.9567032119939689 and parameters: {'learning_rate': 0.13849796341637374, 'n_estimators': 300, 'max_depth': 5, 'min_child_weight': 3, 'gamma': 0.22543004674695347, 'subsample': 0.6886735113819117, 'colsample_bytree': 0.8310615566568952, 'reg_alpha': 0.02591233175729879, 'reg_lambda': 7.381454300310017}. Best is trial 23 with value: 0.9575655020584227.
# [I 2025-04-21 21:59:31,375] Trial 25 finished with value: 0.9551065250721835 and parameters: {'learning_rate': 0.14985440225215954, 'n_estimators': 373, 'max_depth': 4, 'min_child_weight': 3, 'gamma': 0.24189396048723344, 'subsample': 0.6599977810257429, 'colsample_bytree': 0.9186361276989201, 'reg_alpha': 2.5914390472779125, 'reg_lambda': 8.935484627867936}. Best is trial 23 with value: 0.9575655020584227.
# [I 2025-04-21 22:01:12,270] Trial 26 finished with value: 0.9555531481528461 and parameters: {'learning_rate': 0.08387430384130871, 'n_estimators': 345, 'max_depth': 5, 'min_child_weight': 2, 'gamma': 0.2123607023732919, 'subsample': 0.7589644253638828, 'colsample_bytree': 0.8184973475831974, 'reg_alpha': 1.6676627753929403, 'reg_lambda': 6.5544405163250055}. Best is trial 23 with value: 0.9575655020584227.
# [I 2025-04-21 22:02:51,254] Trial 27 finished with value: 0.9564263685042014 and parameters: {'learning_rate': 0.10789878351226954, 'n_estimators': 361, 'max_depth': 5, 'min_child_weight': 4, 'gamma': 0.15967289958414327, 'subsample': 0.635251044064872, 'colsample_bytree': 0.7119682048653763, 'reg_alpha': 3.3292061735058143, 'reg_lambda': 7.949982000632177}. Best is trial 23 with value: 0.9575655020584227.
# [I 2025-04-21 22:04:58,093] Trial 28 finished with value: 0.950196843823757 and parameters: {'learning_rate': 0.05281810067215631, 'n_estimators': 375, 'max_depth': 4, 'min_child_weight': 3, 'gamma': 0.2734863593243781, 'subsample': 0.7155599176454137, 'colsample_bytree': 0.9075742347354961, 'reg_alpha': 0.7150302926128306, 'reg_lambda': 0.11673896648911786}. Best is trial 23 with value: 0.9575655020584227.
# [I 2025-04-21 22:07:17,229] Trial 29 finished with value: 0.9482501075465043 and parameters: {'learning_rate': 0.021259703145640158, 'n_estimators': 378, 'max_depth': 5, 'min_child_weight': 4, 'gamma': 0.1604831988141453, 'subsample': 0.9403796431200658, 'colsample_bytree': 0.6655775498166886, 'reg_alpha': 8.446693901738259, 'reg_lambda': 9.423926491313535}. Best is trial 23 with value: 0.9575655020584227.
# Best hyperparameters: {'learning_rate': 0.16147509326207363, 'n_estimators': 360, 'max_depth': 5, 'min_child_weight': 3, 'gamma': 0.23255551949345582, 'subsample': 0.6919010893031594, 'colsample_bytree': 0.828723545372629, 'reg_alpha': 0.0353238029105275, 'reg_lambda': 9.005881861726515}
# C:\Users\Acer\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [22:07:18] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "random_seed" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.828723545372629, device=None,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, feature_types=None, gamma=0.23255551949345582,
#              grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.16147509326207363,
#              max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=5, max_leaves=None,
#              min_child_weight=3, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=360, n_jobs=None,
#              num_parallel_tree=None, random_seed=42, ...)

# %%
best_params= {'learning_rate': 0.16147509326207363, 
         'n_estimators': 360, 
         'max_depth': 5, 
         'min_child_weight': 3, 
         'gamma': 0.23255551949345582, 
         'subsample': 0.6919010893031594, 
         'colsample_bytree': 0.828723545372629, 
         'reg_alpha': 0.0353238029105275, 
         'reg_lambda': 9.005881861726515}

# %%
best_params = best_params

model = xgb.XGBRegressor(**best_params)

model.fit(X_train, y_train, verbose=False)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.828723545372629, device=None,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, feature_types=None, gamma=0.23255551949345582,
#              grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.16147509326207363,
#              max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=5, max_leaves=None,
#              min_child_weight=3, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=360, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
y_pred = model.predict(X_test)

# %%
r2_score(y_test, y_pred)
# Out:
# 0.9581748503590413

# %%
root_mean_squared_error(y_test, y_pred)
# Out:
# 0.24904922601818957

# %%
y_test_exp = np.exp(y_test)
y_pred_exp =np.exp(y_pred)

# %%
root_mean_squared_error(y_test_exp,y_pred_exp)
# Out:
# 26.16363125122596

# %%
plt.title("Yhat vs Y")
plt.plot(y_pred_exp, y_test_exp,"o")
plt.plot([0,1000],[0,1000],"b")
plt.xlabel("yhat")
plt.ylabel("y")
plt.show()

# %%
def plot_residuals(y_test_exp, y_pred_exp):
    residuals = y_test_exp - y_pred_exp
    plt.figure(figsize=(7, 5))
    sns.scatterplot(x=y_pred_exp, y=residuals, alpha=0.6)
    plt.axhline(y=0, color="red", linestyle="--")
    plt.xlabel("Predicted Values (ŷ)")
    plt.ylabel("Residuals (y - ŷ)")
    plt.title("Residual Plot")
    plt.show()

# Call function
plot_residuals(y_test_exp, y_pred_exp)

# %%
import shap
# 1. Create a SHAP explainer
explainer = shap.TreeExplainer(model)

# %%
# 2. Calculate SHAP values for the test set (or any data you want to explain)
shap_values = explainer.shap_values(X_test)

# %%
# 3. Bar Plot: Global feature importance (alternative representation)
shap.summary_plot(shap_values, X_test, plot_type="bar", show=False)

plt.savefig("shap_summary_bar.png", dpi=300, bbox_inches='tight')
