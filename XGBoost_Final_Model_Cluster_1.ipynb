# %%
import pandas as pd
import numpy as np
import xgboost as xgb
from sklearn.model_selection import train_test_split, KFold, cross_val_score
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import make_pipeline
from sklearn.compose import ColumnTransformer
from sklearn.metrics import r2_score, root_mean_squared_error
import optuna
import seaborn as sns
import matplotlib.pyplot as plt
from Funciones import feature_engineering_shuffle

# %%
df = pd.read_parquet("data/train_data/trips_weather_merged.parquet") #Load full Dataset

# %%
df = feature_engineering_shuffle(df) #Apply feature engineering function

# %%
df = pd.get_dummies(df,columns=["weekday","is_weekend", "rush_hour","is_holiday","LocationID"],drop_first=True,dtype=float)

# %%
df_cluster_1 = df[df["cluster"]==1] #Filter df to get cluster 1 data only
y = df_cluster_1["Total_Trips"]
X = df_cluster_1.drop(columns=["Total_Trips","tpep_pickup_hour", "Location*Hour","cluster"])
#Train-Test split, stratified using Location*Hour
X_train, X_test, y_train, y_test = train_test_split(X,y,random_state=42, shuffle=True, test_size=0.2, stratify=df_cluster_1["Location*Hour"])

# %%
def objective(trial):
    # Define hyperparameter search space
    params = {
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.2, log=True),
        'n_estimators': trial.suggest_int('n_estimators', 300, 400),
        'max_depth': trial.suggest_int('max_depth', 3, 5),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 5),
        'gamma': trial.suggest_float('gamma', 0, 0.3),
        'subsample': trial.suggest_float('subsample', 0.6, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.6, 1.0),
        'reg_alpha': trial.suggest_float('reg_alpha', 0, 10),
        'reg_lambda': trial.suggest_float('reg_lambda', 0, 10),
        'objective': 'reg:squarederror'
    }

    # Define cross-validation strategy
    cv = KFold(n_splits=4, shuffle=True, random_state=42)

    model = xgb.XGBRegressor(**params, random_state=42)

# Perform cross-validation manually to inverse transform predictions
    scores = []
    for train_index, val_index in cv.split(X_train, y_train): # Use the log-transformed target
        X_train_fold, X_val_fold = X_train.iloc[train_index], X_train.iloc[val_index]
        y_train_fold, y_val_fold = y_train.iloc[train_index], y_train.iloc[val_index]

        model.fit(X_train_fold, y_train_fold, verbose=0)
        predictions = model.predict(X_val_fold)

        score = r2_score(y_val_fold, predictions) # Inverse transform true values too for evaluation
        scores.append(score)

    # Return the mean accuracy across all folds
    return np.mean(scores)

study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=30)

# Best hyperparameters
print("Best hyperparameters:", study.best_params)

best_params = study.best_params

model = xgb.XGBRegressor(**best_params, random_seed=42)

model.fit(X_train, y_train, verbose=False)
# Out:
# [I 2025-04-21 23:46:26,507] A new study created in memory with name: no-name-1c4813c2-8de7-4d82-93ed-9e4f0c18fac5
# [I 2025-04-21 23:49:36,176] Trial 0 finished with value: 0.9231725050097659 and parameters: {'learning_rate': 0.12788744827011828, 'n_estimators': 378, 'max_depth': 4, 'min_child_weight': 3, 'gamma': 0.24705267011157814, 'subsample': 0.7859491612599435, 'colsample_bytree': 0.6728011213973124, 'reg_alpha': 2.136424820134959, 'reg_lambda': 9.553923980800793}. Best is trial 0 with value: 0.9231725050097659.
# [I 2025-04-21 23:53:15,179] Trial 1 finished with value: 0.9141932304593592 and parameters: {'learning_rate': 0.02012233625490967, 'n_estimators': 375, 'max_depth': 4, 'min_child_weight': 1, 'gamma': 0.03039072573255217, 'subsample': 0.7438790675785591, 'colsample_bytree': 0.837604486990106, 'reg_alpha': 1.884126989609095, 'reg_lambda': 4.264999820905221}. Best is trial 0 with value: 0.9231725050097659.
# [I 2025-04-21 23:57:13,005] Trial 2 finished with value: 0.9116869297564278 and parameters: {'learning_rate': 0.012863201647771069, 'n_estimators': 372, 'max_depth': 4, 'min_child_weight': 1, 'gamma': 0.29852729397682665, 'subsample': 0.7260165320465957, 'colsample_bytree': 0.8102276261170412, 'reg_alpha': 4.984752992359863, 'reg_lambda': 6.266054095481034}. Best is trial 0 with value: 0.9231725050097659.
# [I 2025-04-22 00:00:06,614] Trial 3 finished with value: 0.9202495940350539 and parameters: {'learning_rate': 0.19604981859092926, 'n_estimators': 346, 'max_depth': 3, 'min_child_weight': 4, 'gamma': 0.15236543329372962, 'subsample': 0.858041557722157, 'colsample_bytree': 0.6719330799458197, 'reg_alpha': 9.713492220836464, 'reg_lambda': 8.312249444149357}. Best is trial 0 with value: 0.9231725050097659.
# [I 2025-04-22 00:03:36,995] Trial 4 finished with value: 0.9178713107619355 and parameters: {'learning_rate': 0.02584848248028712, 'n_estimators': 307, 'max_depth': 5, 'min_child_weight': 5, 'gamma': 0.01222054016832309, 'subsample': 0.7320866912228688, 'colsample_bytree': 0.8492333175018205, 'reg_alpha': 1.7071346776990637, 'reg_lambda': 8.721805200636599}. Best is trial 0 with value: 0.9231725050097659.
# [I 2025-04-22 00:06:27,036] Trial 5 finished with value: 0.9226011920429005 and parameters: {'learning_rate': 0.13406104428580598, 'n_estimators': 315, 'max_depth': 4, 'min_child_weight': 5, 'gamma': 0.09444779102762234, 'subsample': 0.8082950067001784, 'colsample_bytree': 0.9275621241574328, 'reg_alpha': 2.4738407131577036, 'reg_lambda': 6.978621549054855}. Best is trial 0 with value: 0.9231725050097659.
# [I 2025-04-22 00:09:29,925] Trial 6 finished with value: 0.9077902915637761 and parameters: {'learning_rate': 0.015653493505054215, 'n_estimators': 336, 'max_depth': 3, 'min_child_weight': 4, 'gamma': 0.09992024018475174, 'subsample': 0.761855010777827, 'colsample_bytree': 0.9623188565067704, 'reg_alpha': 1.8471984650159434, 'reg_lambda': 4.802814209508087}. Best is trial 0 with value: 0.9231725050097659.
# [I 2025-04-22 00:13:06,146] Trial 7 finished with value: 0.924670797076847 and parameters: {'learning_rate': 0.1800578761464885, 'n_estimators': 387, 'max_depth': 4, 'min_child_weight': 3, 'gamma': 0.1950203316988312, 'subsample': 0.6513340076132811, 'colsample_bytree': 0.8629649039740503, 'reg_alpha': 9.88861322820038, 'reg_lambda': 1.0721854774857154}. Best is trial 7 with value: 0.924670797076847.
# [I 2025-04-22 00:16:19,153] Trial 8 finished with value: 0.9187190693574023 and parameters: {'learning_rate': 0.12344431320950144, 'n_estimators': 367, 'max_depth': 3, 'min_child_weight': 5, 'gamma': 0.07753805340742412, 'subsample': 0.8748898579741502, 'colsample_bytree': 0.9314351596838061, 'reg_alpha': 3.501498575574468, 'reg_lambda': 1.7218511975976947}. Best is trial 7 with value: 0.924670797076847.
# [I 2025-04-22 00:19:17,638] Trial 9 finished with value: 0.9081041090865728 and parameters: {'learning_rate': 0.017030943527270744, 'n_estimators': 310, 'max_depth': 3, 'min_child_weight': 2, 'gamma': 0.22824478503258747, 'subsample': 0.7436569790292974, 'colsample_bytree': 0.7650268279656651, 'reg_alpha': 5.304732558549298, 'reg_lambda': 5.788609794810762}. Best is trial 7 with value: 0.924670797076847.
# [I 2025-04-22 00:23:31,854] Trial 10 finished with value: 0.9227508609407723 and parameters: {'learning_rate': 0.05549213553128621, 'n_estimators': 398, 'max_depth': 5, 'min_child_weight': 3, 'gamma': 0.17839049042020846, 'subsample': 0.6019639892722539, 'colsample_bytree': 0.7386907569200997, 'reg_alpha': 9.874003203336223, 'reg_lambda': 0.23109539188301398}. Best is trial 7 with value: 0.924670797076847.
# [I 2025-04-22 00:27:10,411] Trial 11 finished with value: 0.9206266099652649 and parameters: {'learning_rate': 0.07153321321465662, 'n_estimators': 399, 'max_depth': 4, 'min_child_weight': 3, 'gamma': 0.23423336001066347, 'subsample': 0.9513271856095027, 'colsample_bytree': 0.6000034149861458, 'reg_alpha': 7.511496182344561, 'reg_lambda': 2.8241839976291114}. Best is trial 7 with value: 0.924670797076847.
# [I 2025-04-22 00:30:55,467] Trial 12 finished with value: 0.9249938135213885 and parameters: {'learning_rate': 0.0954624649058068, 'n_estimators': 380, 'max_depth': 5, 'min_child_weight': 2, 'gamma': 0.2286576510977633, 'subsample': 0.6199827350182164, 'colsample_bytree': 0.6669969639135751, 'reg_alpha': 0.2901520886232001, 'reg_lambda': 9.8318873321999}. Best is trial 12 with value: 0.9249938135213885.
# [I 2025-04-22 00:35:19,004] Trial 13 finished with value: 0.9246476009246751 and parameters: {'learning_rate': 0.08281542544193744, 'n_estimators': 386, 'max_depth': 5, 'min_child_weight': 2, 'gamma': 0.1952594260573556, 'subsample': 0.600320558855446, 'colsample_bytree': 0.887492132211018, 'reg_alpha': 0.026245378712898726, 'reg_lambda': 3.36380106615319}. Best is trial 12 with value: 0.9249938135213885.
# [I 2025-04-22 00:39:05,030] Trial 14 finished with value: 0.9201367991845082 and parameters: {'learning_rate': 0.036527265624764514, 'n_estimators': 350, 'max_depth': 5, 'min_child_weight': 2, 'gamma': 0.28132036055945214, 'subsample': 0.6588905505444582, 'colsample_bytree': 0.9983043021700606, 'reg_alpha': 7.679089754825244, 'reg_lambda': 0.37683601044363524}. Best is trial 12 with value: 0.9249938135213885.
# [I 2025-04-22 00:42:26,415] Trial 15 finished with value: 0.9267842463733755 and parameters: {'learning_rate': 0.18972331006881477, 'n_estimators': 360, 'max_depth': 5, 'min_child_weight': 2, 'gamma': 0.1945738960737595, 'subsample': 0.6711648020855602, 'colsample_bytree': 0.7082182371108593, 'reg_alpha': 0.06337472926663015, 'reg_lambda': 1.8489691169609355}. Best is trial 15 with value: 0.9267842463733755.
# [I 2025-04-22 00:46:10,574] Trial 16 finished with value: 0.9242576370126194 and parameters: {'learning_rate': 0.0801352380144774, 'n_estimators': 364, 'max_depth': 5, 'min_child_weight': 2, 'gamma': 0.14961121300733016, 'subsample': 0.6690946878251772, 'colsample_bytree': 0.6910247485428993, 'reg_alpha': 0.7581944036366903, 'reg_lambda': 2.4156803823494784}. Best is trial 15 with value: 0.9267842463733755.
# [I 2025-04-22 00:49:12,233] Trial 17 finished with value: 0.9244916525050513 and parameters: {'learning_rate': 0.09875293883874552, 'n_estimators': 329, 'max_depth': 5, 'min_child_weight': 1, 'gamma': 0.25909682833628306, 'subsample': 0.6881226236422933, 'colsample_bytree': 0.6232518342115632, 'reg_alpha': 0.14193593053328785, 'reg_lambda': 7.494919823423761}. Best is trial 15 with value: 0.9267842463733755.
# [I 2025-04-22 00:52:24,162] Trial 18 finished with value: 0.9223325666529829 and parameters: {'learning_rate': 0.053529033376385676, 'n_estimators': 355, 'max_depth': 5, 'min_child_weight': 2, 'gamma': 0.1323842519208449, 'subsample': 0.62528049462453, 'colsample_bytree': 0.7260633030937232, 'reg_alpha': 4.10295533183154, 'reg_lambda': 3.6763746611401644}. Best is trial 15 with value: 0.9267842463733755.
# [I 2025-04-22 00:56:00,718] Trial 19 finished with value: 0.9262313259651346 and parameters: {'learning_rate': 0.1528176882362268, 'n_estimators': 361, 'max_depth': 5, 'min_child_weight': 1, 'gamma': 0.20561269537314691, 'subsample': 0.7012654486893385, 'colsample_bytree': 0.6343826678302572, 'reg_alpha': 3.1824447186111056, 'reg_lambda': 5.744913307243765}. Best is trial 15 with value: 0.9267842463733755.
# [I 2025-04-22 00:59:28,255] Trial 20 finished with value: 0.9263179604928948 and parameters: {'learning_rate': 0.15692173951556623, 'n_estimators': 359, 'max_depth': 5, 'min_child_weight': 1, 'gamma': 0.19851531968333716, 'subsample': 0.7074380342223467, 'colsample_bytree': 0.6315552241984732, 'reg_alpha': 3.2163972187041123, 'reg_lambda': 5.477864621460591}. Best is trial 15 with value: 0.9267842463733755.
# [I 2025-04-22 01:03:06,116] Trial 21 finished with value: 0.9264012439602904 and parameters: {'learning_rate': 0.16143952067115677, 'n_estimators': 359, 'max_depth': 5, 'min_child_weight': 1, 'gamma': 0.19923540059061112, 'subsample': 0.7035709282397524, 'colsample_bytree': 0.6325747585310474, 'reg_alpha': 3.28823264380637, 'reg_lambda': 5.548377007735665}. Best is trial 15 with value: 0.9267842463733755.
# [I 2025-04-22 01:06:13,090] Trial 22 finished with value: 0.9264053981835039 and parameters: {'learning_rate': 0.17211851421717328, 'n_estimators': 345, 'max_depth': 5, 'min_child_weight': 1, 'gamma': 0.17170237760369794, 'subsample': 0.6951885258773304, 'colsample_bytree': 0.7141064186789986, 'reg_alpha': 5.457601039374654, 'reg_lambda': 4.914357018301615}. Best is trial 15 with value: 0.9267842463733755.
# [I 2025-04-22 01:09:52,722] Trial 23 finished with value: 0.9250471328983157 and parameters: {'learning_rate': 0.11370526522601081, 'n_estimators': 339, 'max_depth': 5, 'min_child_weight': 1, 'gamma': 0.1609798065854944, 'subsample': 0.8042852418011389, 'colsample_bytree': 0.7241730980630242, 'reg_alpha': 6.480735202036643, 'reg_lambda': 4.310919004536519}. Best is trial 15 with value: 0.9267842463733755.
# [I 2025-04-22 01:12:48,858] Trial 24 finished with value: 0.9262544648938982 and parameters: {'learning_rate': 0.18573433809195886, 'n_estimators': 330, 'max_depth': 5, 'min_child_weight': 1, 'gamma': 0.11255827402624453, 'subsample': 0.9944561835702873, 'colsample_bytree': 0.7678742174616846, 'reg_alpha': 5.244757904545384, 'reg_lambda': 6.9006111752074455}. Best is trial 15 with value: 0.9267842463733755.
# [I 2025-04-22 01:16:23,290] Trial 25 finished with value: 0.9202446362772023 and parameters: {'learning_rate': 0.037029987819581375, 'n_estimators': 345, 'max_depth': 5, 'min_child_weight': 2, 'gamma': 0.16753882027718067, 'subsample': 0.6714449156905848, 'colsample_bytree': 0.6970116561134441, 'reg_alpha': 6.528271850305758, 'reg_lambda': 1.5938503522296437}. Best is trial 15 with value: 0.9267842463733755.
# [I 2025-04-22 01:19:18,647] Trial 26 finished with value: 0.9236693488387384 and parameters: {'learning_rate': 0.15593499267903865, 'n_estimators': 353, 'max_depth': 4, 'min_child_weight': 1, 'gamma': 0.13964092737250222, 'subsample': 0.8383138781098239, 'colsample_bytree': 0.7743180603054436, 'reg_alpha': 4.119782162714696, 'reg_lambda': 4.891669128854975}. Best is trial 15 with value: 0.9267842463733755.
# [I 2025-04-22 01:22:21,015] Trial 27 finished with value: 0.9244282195663773 and parameters: {'learning_rate': 0.09992903759928314, 'n_estimators': 328, 'max_depth': 5, 'min_child_weight': 2, 'gamma': 0.21338281879431595, 'subsample': 0.7755836171358228, 'colsample_bytree': 0.7062804709226544, 'reg_alpha': 6.55036952764545, 'reg_lambda': 2.8360527704260625}. Best is trial 15 with value: 0.9267842463733755.
# [I 2025-04-22 01:24:45,378] Trial 28 finished with value: 0.9197644465146481 and parameters: {'learning_rate': 0.06837861495643863, 'n_estimators': 319, 'max_depth': 4, 'min_child_weight': 1, 'gamma': 0.18051839143782977, 'subsample': 0.6417312094338781, 'colsample_bytree': 0.6533074673211953, 'reg_alpha': 4.472378301004826, 'reg_lambda': 3.6880882153824968}. Best is trial 15 with value: 0.9267842463733755.
# [I 2025-04-22 01:27:39,043] Trial 29 finished with value: 0.9256591237592457 and parameters: {'learning_rate': 0.1297660846450295, 'n_estimators': 339, 'max_depth': 5, 'min_child_weight': 4, 'gamma': 0.2504358393124647, 'subsample': 0.7019499215304168, 'colsample_bytree': 0.7477540194063571, 'reg_alpha': 0.8490498951845202, 'reg_lambda': 8.22208884652726}. Best is trial 15 with value: 0.9267842463733755.
# Best hyperparameters: {'learning_rate': 0.18972331006881477, 'n_estimators': 360, 'max_depth': 5, 'min_child_weight': 2, 'gamma': 0.1945738960737595, 'subsample': 0.6711648020855602, 'colsample_bytree': 0.7082182371108593, 'reg_alpha': 0.06337472926663015, 'reg_lambda': 1.8489691169609355}
# C:\Users\Acer\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [01:27:42] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "random_seed" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.7082182371108593, device=None,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, feature_types=None, gamma=0.1945738960737595,
#              grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.18972331006881477,
#              max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=5, max_leaves=None,
#              min_child_weight=2, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=360, n_jobs=None,
#              num_parallel_tree=None, random_seed=42, ...)

# %%
model = xgb.XGBRegressor(**best_params)

model.fit(X_train, y_train, verbose=False)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.7082182371108593, device=None,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, feature_types=None, gamma=0.1945738960737595,
#              grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.18972331006881477,
#              max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=5, max_leaves=None,
#              min_child_weight=2, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=360, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
y_pred = model.predict(X_test)

# %%
r2_score(y_test, y_pred)
# Out:
# 0.9270633165737122

# %%
root_mean_squared_error(y_test, y_pred)
# Out:
# 0.3759956871852181

# %%
y_pred_exp = np.exp(y_pred)
y_test_exp = np.exp(y_test)

# %%
root_mean_squared_error(y_test_exp, y_pred_exp)
# Out:
# 4.726890327063607

# %%
plt.title("Yhat vs Y")
plt.plot(y_pred_exp, y_test_exp,"o")
plt.plot([0,180],[0,180],"b")
plt.xlabel("yhat")
plt.ylabel("y")
plt.show()

# %%
def plot_residuals(y_test_exp, y_pred_exp):
    residuals = y_test_exp - y_pred_exp
    plt.figure(figsize=(7, 5))
    sns.scatterplot(x=y_pred_exp, y=residuals, alpha=0.6)
    plt.axhline(y=0, color="red", linestyle="--")
    plt.xlabel("Predicted Values (ŷ)")
    plt.ylabel("Residuals (y - ŷ)")
    plt.title("Residual Plot")
    plt.show()

# Call function
plot_residuals(y_test_exp, y_pred_exp)

# %%
import shap
# 1. Create a SHAP explainer
explainer = shap.TreeExplainer(model)

# %%
# 2. Calculate SHAP values for the test set (or any data you want to explain)
shap_values = explainer.shap_values(X_test)

# %%
# 3. Bar Plot: Global feature importance (alternative representation)
shap.summary_plot(shap_values, X_test, plot_type="bar")
