# %%
import pandas as pd
import numpy as np
import xgboost as xgb
from lightgbm import LGBMRegressor
from catboost import CatBoostRegressor, Pool
from sklearn.model_selection import train_test_split, KFold, cross_val_score
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import r2_score, root_mean_squared_error

# %%
#Hiperparámetros de modelos previamente encontrados utilizando OPTUNA

catboost_params = {'learning_rate': 0.19589334361676058,
 'iterations': 357,
 'depth': 5,
 'l2_leaf_reg': 2.4383355947131355,
 'bagging_temperature': 0.4880588845509045,
 'random_strength': 1.4984300903776795,
 'rsm': 0.7657298876115406}

xgboost_params = {'learning_rate': 0.19897749523532485,
 'n_estimators': 399,
 'max_depth': 5,
 'min_child_weight': 2,
 'gamma': 0.162854039714699,
 'subsample': 0.6430057260063712,
 'colsample_bytree': 0.976575208389519,
 'reg_alpha': 5.932062886045555,
 'reg_lambda': 1.571273639240366}

lightgbm_params = {'n_estimators': 366,
 'learning_rate': 0.19289032026873984,
 'max_depth': 5,
 'subsample': 0.8448599797005143,
 'colsample_bytree': 0.888292577274356,
 'reg_alpha': 0.7880255790817811,
 'reg_lambda': 0.05129584535565534}

# %%
df = pd.read_parquet("trips_weather_merged.parquet") # Cargamos Dataset pre-procesado para el entrenamiento

df= df[df["tpep_pickup_hour"]>"2021-12-31"] # Filtro el dataset para entrenar con datos de 2022 a 2025 (Enero)

df["Location*Hour"] = df.apply(lambda x: str(x["LocationID"])+" "+str(x["pickup_hour"]),axis=1) # Creo columna referencia para estratificar el train/test

df2 = pd.read_csv("df_grouped_location.csv") # Cargo dataset con LocationID y clusters

df = df.merge(df2, on="LocationID", how="left").drop(columns=["Unnamed: 0", "sum","max","mean","median"]) # Uno datasets para agregar columna "cluster"

df = pd.get_dummies(df,columns=["weekday","is_weekend", "rush_hour"],drop_first=True,dtype=float) # Convierto en Dummies las variables categóricas

df_cluster_0 = df[df["cluster"]==0] # Filtro el dataset para entrenar SOLO con el cluster 0

# Dividimos dataset en train y test, shuffle True y estratificación con la columna "Location*Hour"
y = df_cluster_0["Total_Trips"] 
X = df_cluster_0.drop(columns=["Total_Trips","tpep_pickup_hour", "Location*Hour","cluster"])
X_train, X_test, y_train, y_test = train_test_split(X,y,random_state=42, shuffle=True, test_size=0.2, stratify=df_cluster_0["Location*Hour"])

# %%
#Instanciamos modelos
LightGBM = LGBMRegressor(**lightgbm_params, random_state=42)
XGBoost = xgb.XGBRegressor(**xgboost_params, random_state=42)
CatBoost = CatBoostRegressor(**catboost_params, random_seed=42)

Models = [LightGBM,XGBoost,CatBoost]

Modelos = []

y_train_log = np.log1p(y_train) # Use np.log1p to handle potential zeros

for model in Models:
    resultados = {}
    model.fit(X_train, y_train_log)
    y_pred = model.predict(X_test)
    y_pred_exp = np.exp(y_pred)
    resultados["modelo"] = model
    resultados["r2"]=r2_score(y_test, y_pred_exp)
    resultados["rmse"]=root_mean_squared_error(y_test, y_pred_exp)
    Modelos.append(resultados)
# Out:
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.012972 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 914
# [LightGBM] [Info] Number of data points in the train set: 346356, number of used features: 18
# [LightGBM] [Info] Start training from score 4.473038
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# 0:	learn:
# 94:	learn: 0.4127918	total: 3.87s	remaining: 10.7s
# 95:	learn: 0.4120881	total: 3.91s	remaining: 10.6s
# 96:	learn: 0.4116729	total: 3.96s	remaining: 10.6s
# 97:	learn: 0.4110005	total: 4.01s	remaining: 10.6s
# 98:	learn: 0.4106270	total: 4.12s	remaining: 10.7s
# 99:	learn: 0.4070266	total: 4.2s	remaining: 10.8s
# 100:	learn: 0.4060622	total: 4.26s	remaining: 10.8s
# 101:	learn: 0.4053606	total: 4.34s	remaining: 10.8s
# 102:	learn: 0.4045576	total: 4.41s	remaining: 10.9s
# 103:	learn: 0.4040528	total: 4.49s	remaining: 10.9s
# 104:	learn: 0.4037189	total: 4.55s	remaining: 10.9s
# 105:	learn: 0.4032895	total: 4.63s	remaining: 11s
# 106:	learn: 0.4026017	total: 4.68s	remaining: 10.9s
# 107:	learn: 0.4021248	total: 4.77s	remaining: 11s
# 108:	learn: 0.4018610	total: 4.84s	remaining: 11s
# 109:	learn: 0.4015895	total: 4.92s	remaining: 11s
# 110:	learn: 0.4009362	total: 4.99s	remaining: 11.1s
# 111:	learn: 0.4004276	total: 5.05s	remaining: 11.1s
# 112:	learn: 0.4000925	total: 5.12s	remaining: 11s
# 113:	learn: 0.3996944	total: 5.18s	remaining: 11s
# 114:	learn: 0.3982056	total: 5.23s	remaining: 11s
# 115:	learn: 0.3978181	total: 5.29s	remaining: 11s
# 116:	learn: 0.3975444	total: 5.34s	remaining: 11s
# 117:	learn: 0.3967454	total: 5.39s	remaining: 10.9s
# 118:	learn: 0.3964671	total: 5.45s	remaining: 10.9s
# 119:	learn: 0.3961589	total: 5.49s	remaining: 10.8s
# 120:	learn: 0.3957085	total: 5.54s	remaining: 10.8s
# 121:	learn: 0.3955030	total: 5.58s	remaining: 10.8s
# 122:	learn: 0.3947108	total: 5.62s	remaining: 10.7s
# 123:	learn: 0.3939695	total: 5.67s	remaining: 10.7s
# 124:	learn: 0.3932597	total: 5.72s	remaining: 10.6s
# 125:	learn: 0.3925196	total: 5.76s	remaining: 10.6s
# 126:	learn: 0.3918529	total: 5.81s	remaining: 10.5s
# 127:	learn: 0.3912939	total: 5.85s	remaining: 10.5s
# 128:	learn: 0.3905076	total: 5.89s	remaining: 10.4s
# 129:	learn: 0.3901032	total: 5.94s	remaining: 10.4s
# 130:	learn: 0.3896659	total: 5.98s	remaining: 10.3s
# 131:	learn: 0.3893493	total: 6.03s	remaining: 10.3s
# 132:	learn: 0.3889339	total: 6.07s	remaining: 10.2s
# 133:	learn: 0.3881102	total: 6.11s	remaining: 10.2s
# 134:	learn: 0.3876320	total: 6.16s	remaining: 10.1s
# 135:	learn: 0.3869438	total: 6.19s	remaining: 10.1s
# 136:	learn: 0.3866133	total: 6.23s	remaining: 10s
# 137:	learn: 0.3861433	total: 6.28s	remaining: 9.96s
# 138:	learn: 0.3856877	total: 6.32s	remaining: 9.9s
# 229:	learn: 0.3567839	total: 10.3s	remaining: 5.7s
# 230:	learn: 0.3566040	total: 10.4s	remaining: 5.67s
# 231:	learn: 0.3562314	total: 10.5s	remaining: 5.63s
# 232:	learn: 0.3561134	total: 10.5s	remaining: 5.6s
# 233:	learn: 0.3559057	total: 10.6s	remaining: 5.57s
# 234:	learn: 0.3555547	total: 10.6s	remaining: 5.52s
# 235:	learn: 0.3554877	total: 10.7s	remaining: 5.49s
# 236:	learn: 0.3553987	total: 10.8s	remaining: 5.45s
# 237:	learn: 0.3551553	total: 10.8s	remaining: 5.41s
# 238:	learn: 0.3549895	total: 10.9s	remaining: 5.36s
# 239:	learn: 0.3548785	total: 10.9s	remaining: 5.32s
# 240:	learn: 0.3534655	total: 11s	remaining: 5.28s
# 241:	learn: 0.3532382	total: 11.1s	remaining: 5.25s
# 242:	learn: 0.3531491	total: 11.1s	remaining: 5.21s
# 243:	learn: 0.3530504	total: 11.2s	remaining: 5.17s
# 244:	learn: 0.3528442	total: 11.2s	remaining: 5.13s
# 245:	learn: 0.3524742	total: 11.3s	remaining: 5.09s
# 246:	learn: 0.3521376	total: 11.3s	remaining: 5.04s
# 247:	learn: 0.3519976	total: 11.4s	remaining: 5s
# 248:	learn: 0.3518419	total: 11.4s	remaining: 4.95s
# 249:	learn: 0.3517730	total: 11.5s	remaining: 4.9s
# 250:	learn: 0.3516733	total: 11.5s	remaining: 4.86s
# 251:	learn: 0.3512231	total: 11.5s	remaining: 4.81s
# 252:	learn: 0.3509112	total: 11.6s	remaining: 4.76s
# 253:	learn: 0.3508140	total: 11.6s	remaining: 4.72s
# 254:	learn: 0.3505884	total: 11.7s	remaining: 4.67s
# 255:	learn: 0.3504562	total: 11.7s	remaining: 4.62s
# 256:	learn: 0.3503167	total: 11.8s	remaining: 4.58s
# 257:	learn: 0.3501559	total: 11.8s	remaining: 4.53s
# 258:	learn: 0.3500136	total: 11.9s	remaining: 4.49s
# 259:	learn: 0.3499246	total: 11.9s	remaining: 4.45s
# 260:	learn: 0.3497155	total: 12s	remaining: 4.41s
# 261:	learn: 0.3495538	total: 12.1s	remaining: 4.37s
# 262:	learn: 0.3494575	total: 12.1s	remaining: 4.32s
# 263:	learn: 0.3493346	total: 12.1s	remaining: 4.27s
# 264:	learn: 0.3492433	total: 12.2s	remaining: 4.22s
# 265:	learn: 0.3491526	total: 12.2s	remaining: 4.17s
# 266:	learn: 0.3489935	total: 12.2s	remaining: 4.13s
# 267:	learn: 0.3479771	total: 12.3s	remaining: 4.08s
# 268:	learn: 0.3476636	total: 12.3s	remaining: 4.03s
# 269:	learn: 0.3475040	total: 12.4s	remaining: 3.98s
# 270:	learn: 0.3473136	total: 12.4s	remaining: 3.93s
# 271:	learn: 0.3472002	total: 12.4s	remaining: 3.89s
# 272:	learn: 0.3441460	total: 12.5s	remaining: 3.84s
# 273:	learn: 0.3440021	total: 12.5s	remaining: 3.79s
# 274:	learn: 0.3438058	total: 12.6s	remaining: 3.75s
# 275:	learn: 0.3434907	total: 12.6s	remaining: 3.7s
# 276:	learn: 0.3434139	total: 12.6s	remaining: 3.65s
# 277:	learn: 0.3430321	total: 12.7s	remaining: 3.6s
# 278:	learn: 0.3428903	total: 12.7s	remaining: 3.56s
# 279:	learn: 0.3424753	total: 12.8s	remaining: 3.51s
# 280:	learn: 0.3423045	total: 12.8s	remaining: 3.46s
# 281:	learn: 0.3422336	total: 12.9s	remaining: 3.42s
# 282:	learn: 0.3420329	total: 12.9s	remaining: 3.37s
# 283:	learn: 0.3419155	total: 12.9s	remaining: 3.32s
# 284:	learn: 0.3417908	total: 13s	remaining: 3.27s
# 285:	learn: 0.3416554	total: 13s	remaining: 3.23s
# 286:	learn: 0.3415760	total: 13s	remaining: 3.18s
# 287:	learn: 0.3414630	total: 13.1s	remaining: 3.13s
# 288:	learn: 0.3413742	total: 13.1s	remaining: 3.08s
# 289:	learn: 0.3412361	total: 13.1s	remaining: 3.04s
# 290:	learn: 0.3410912	total: 13.2s	remaining: 2.99s
# 291:	learn: 0.3409287	total: 13.2s	remaining: 2.94s
# 292:	learn: 0.3407404	total: 13.3s	remaining: 2.9s
# 293:	learn: 0.3406539	total: 13.3s	remaining: 2.85s
# 294:	learn: 0.3405286	total: 13.3s	remaining: 2.8s
# 295:	learn: 0.3403955	total: 13.4s	remaining: 2.75s
# 296:	learn: 0.3402245	total: 13.4s	remaining: 2.71s
# 297:	learn: 0.3400661	total: 13.4s	remaining: 2.66s
# 298:	learn: 0.3399913	total: 13.5s	remaining: 2.62s
# 299:	learn: 0.3399067	total: 13.5s	remaining: 2.57s
# 300:	learn: 0.3395966	total: 13.6s	remaining: 2.52s
# 301:	learn: 0.3395062	total: 13.6s	remaining: 2.48s
# 302:	learn: 0.3394554	total: 13.6s	remaining: 2.43s
# 303:	learn: 0.3393248	total: 13.7s	remaining: 2.38s
# 304:	learn: 0.3392604	total: 13.7s	remaining: 2.34s
# 305:	learn: 0.3391766	total: 13.7s	remaining: 2.29s
# 306:	learn: 0.3382414	total: 13.8s	remaining: 2.24s
# 307:	learn: 0.3380788	total: 13.8s	remaining: 2.2s
# 308:	learn: 0.3380177	total: 13.9s	remaining: 2.15s
# 309:	learn: 0.3379056	total: 13.9s	remaining: 2.11s
# 310:	learn: 0.3378282	total: 13.9s	remaining: 2.06s
# 311:	learn: 0.3375616	total: 14s	remaining: 2.02s
# 312:	learn: 0.3364937	total: 14s	remaining: 1.97s
# 313:	learn: 0.3363458	total: 14s	remaining: 1.92s
# 314:	learn: 0.3362147	total: 14.1s	remaining: 1.88s
# 315:	learn: 0.3360682	total: 14.1s	remaining: 1.83s
# 316:	learn: 0.3357364	total: 14.2s	remaining: 1.79s
# 317:	learn: 0.3355468	total: 14.2s	remaining: 1.74s
# 318:	learn: 0.3354206	total: 14.3s	remaining: 1.7s
# 319:	learn: 0.3349554	total: 14.3s	remaining: 1.65s
# 320:	learn: 0.3347760	total: 14.3s	remaining: 1.61s
# 321:	learn: 0.3346260	total: 14.4s	remaining: 1.56s
# 322:	learn: 0.3345899	total: 14.4s	remaining: 1.52s
# 323:	learn: 0.3345132	total: 14.4s	remaining: 1.47s
# 324:	learn: 0.3344580	total: 14.5s	remaining: 1.43s
# 325:	learn: 0.3343460	total: 14.5s	remaining: 1.38s
# 326:	learn: 0.3342592	total: 14.6s	remaining: 1.33s
# 327:	learn: 0.3332502	total: 14.6s	remaining: 1.29s
# 328:	learn: 0.3330381	total: 14.6s	remaining: 1.25s
# 329:	learn: 0.3329344	total: 14.7s	remaining: 1.2s
# 330:	learn: 0.3328431	total: 14.7s	remaining: 1.16s
# 331:	learn: 0.3327801	total: 14.8s	remaining: 1.11s
# 332:	learn: 0.3326761	total: 14.8s	remaining: 1.07s
# 333:	learn: 0.3325016	total: 14.8s	remaining: 1.02s
# 334:	learn: 0.3322141	total: 14.9s	remaining: 977ms
# 335:	learn: 0.3320980	total: 14.9s	remaining: 932ms
# 336:	learn: 0.3319731	total: 14.9s	remaining: 887ms
# 337:	learn: 0.3318557	total: 15s	remaining: 843ms
# 338:	learn: 0.3317298	total: 15.1s	remaining: 799ms
# 339:	learn: 0.3315936	total: 15.1s	remaining: 756ms
# 340:	learn: 0.3315157	total: 15.2s	remaining: 712ms
# 341:	learn: 0.3313638	total: 15.2s	remaining: 669ms
# 342:	learn: 0.3312217	total: 15.3s	remaining: 625ms
# 343:	learn: 0.3311349	total: 15.3s	remaining: 580ms
# 344:	learn: 0.3309333	total: 15.4s	remaining: 535ms
# 345:	learn: 0.3308130	total: 15.4s	remaining: 491ms
# 346:	learn: 0.3306904	total: 15.5s	remaining: 446ms
# 347:	learn: 0.3305588	total: 15.5s	remaining: 402ms
# 348:	learn: 0.3304165	total: 15.6s	remaining: 357ms
# 349:	learn: 0.3303649	total: 15.6s	remaining: 313ms
# 350:	learn: 0.3302945	total: 15.7s	remaining: 268ms
# 351:	learn: 0.3302283	total: 15.7s	remaining: 223ms
# 352:	learn: 0.3301399	total: 15.8s	remaining: 179ms
# 353:	learn: 0.3300633	total: 15.8s	remaining: 134ms
# 354:	learn: 0.3299715	total: 15.8s	remaining: 89.2ms
# 355:	learn: 0.3299217	total: 15.9s	remaining: 44.6ms
# 356:	learn: 0.3298549	total: 15.9s	remaining: 0us

# %%
pd.DataFrame(Modelos)
# Out:
#                                               modelo        r2       rmse
# 0  LGBMRegressor(colsample_bytree=0.8882925772743...  0.900160  35.685307
# 1  XGBRegressor(base_score=None, booster=None, ca...  0.903185  35.140446
# 2  <catboost.core.CatBoostRegressor object at 0x0...  0.873136  40.225825

# %% [markdown]
# Teniendo en cuenta lo anterior, XGBoost será el modelo final seleccionado ya que tiene las mejores métricas en comparación con los otros dos.

# %%
df = pd.read_parquet("trips_weather_merged.parquet")
